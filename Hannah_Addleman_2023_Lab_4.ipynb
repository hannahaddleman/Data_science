# %% [markdown]
# <a href="https://colab.research.google.com/github/hannahaddleman/Data_science/blob/main/Hannah_Addleman_2023_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
import numpy as np #imports numpy, to use, use np
import matplotlib.pyplot as plt #import matplotlib, to use, use plt.plot

# %%
x = np.array([12, 17, 18, 23, 56, 37, 48]) # gives an array for X, X is population

# %%
# population

# %%
def mean(x): # finds the mean 
    return np.sum(x)/x.shape[0] # retunrs the mean

# %%
def var(x): # finds variable 
    return mean((x - mean(x))**2) # returns the mean of the variable and squares it

# %%
def std(x): # finds standard deviation 
    return np.sqrt(var(x))# retuns standard deviation and multiplys the  variable by x

# %%
mean(x) # the mean
# Out:
# 30.142857142857142

# %%
var(x) # the variable
# Out:
# 247.83673469387756

# %%
std(x) # standard devation
# Out:
# 15.742831215949613

# %% [markdown]
# ### Random Number Generator

# %%
m = 75                 # multiplier, creates m value 
b = 74                 # increment, creates b value 
n = 65537              # modulus, creates n value

# %%
x = 123456      # seed value

# %%
X = np.zeros(50000,) # retuns a new arrawy with 50000

# %%
x = (m * x + b) % n # slopes equation with the percentage of n value whcih is 65537 inside.

# %%
for i in range(X.shape[0]): #The shape attribute for numpy arrays returns the dimensions of the array.

    x = (m * x + b) % n # slopes equation with the percentage of n value whcih is 65537 inside.
    
    X[i] = x # renames x{i} to just i

X /= np.max(X) #function is used to find the element-wise maximum of array elements, takes 2 arrays and retuns it to one

# %%
plt.plot(X[:10],'.') # plots x 10 times

# %%
plt.hist(X); # plots a histogram with x

# %%
plt.hist(X,100); # plots another histogram, bins the data in x and count the number of values in each bin, then draws the distribution

# %%
X # arrays x value
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %%
X # arrays x value again
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %%
X # arrays x value for the third time
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,) # generates 50000 different numbers

# %%
plt.hist(X,100); # plots histogram, distrubutes x 100 times

# %%
np.random.random() # generates random using np
# Out:
# 0.7819591276474576

# %%
r = np.random.random() # chnages np.random.random to r so its quicker and easier(renames it)

# %%
r #np.random.random
# Out:
# 0.6700455875570613

# %%
r = np.random.randint(1,10) #return random integers from the values specified with low

# %%
r # new r
# Out:
# 0.6700455875570613

# %%
r = np.random.randint(1,10,size=(10,2)) # returns name integers with specific details on how to do it

# %%
r # np.random.randint renames
# Out:
# array([[3, 9],
#        [6, 3],
#        [6, 1],
#        [7, 3],
#        [1, 8],
#        [1, 5],
#        [9, 1],
#        [9, 4],
#        [4, 4],
#        [7, 6]])

# %%
np.random.seed(12345) #used to initialize the random number generator.
data = np.random.randn(2, 100) #Setting the seed to a number will always return the same random number:

fig, axs = plt.subplots(2, 2, figsize=(10, 10)) # changes figure size for more sub plots 
axs[0, 0].hist(data[0]) #optional parameter and it contains the integer or sequence or string.
axs[1, 0].scatter(data[0], data[1]) #scatter plot data 
axs[0, 1].plot(data[0], data[1]) # plot data 
axs[1, 1].hist2d(data[0], data[1]) # histogram 2 data 

plt.show()

# %% [markdown]
# Normal Dist Data

# %%
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000) # renames to x

# %%
n,bins,patches = plt.hist(x) #Input values, this takes either a single array or a sequence of arrays which are not required to be of the same length.

# %%
bins # int or sequence or str, default
# Out:
# array([ 43.81966184,  55.32898772,  66.83831359,  78.34763947,
#         89.85696535, 101.36629123, 112.8756171 , 124.38494298,
#        135.89426886, 147.40359473, 158.91292061])

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y) # plots y

# %%
num_bins = 50 # adds number of bins 
n,bins,patches = plt.hist(x, num_bins, density=1) # uses n,bins, and patches to plot
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y) # plots

# %%
def mean(x):# finds the mean 
    return np.sum(x)/x.shape[0] # returns the mean

# %%
def var(x): # finds the variable 
    return mean((x - mean(x))**2) # returns the varable and squares it

# %%
def std(x): # finds the standard deviation
    return np.sqrt(var(x)) # retuns standard devation and squares it

# %%
mean(x) # mean
# Out:
# 99.78475345251351

# %%
std(x) # standard devation
# Out:
# 14.967403929980673

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
def normal_pdf(x,mu,sigma): #A normal continuous random variable
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2)) # returns the normal pdf

# %%
x = np.linspace(-6,6,1000) #Returns num evenly spaced samples, calculated over the interval

# %%
mu = 0 #mean

# %%
sigma = 1 # standard deviation

# %%
pdf = normal_pdf(x,mu,sigma) #Use Normal for demo, replace with custom function pdf

# %%
plt.plot(x,pdf,'.') # plots

# %%
def partial_sums(x): # sum

  y = np.zeros(x.shape)
  
  for n in range(x.shape[0]): # uses n for range 
    
    y[n] = np.sum(x[0:n]) # y is the sum
    
  y = y / np.max(y) # y = the max
    
  return y # returns the sum

# %%
cdf = partial_sums(pdf) #form another sequence based on the sum of the first n terms of int1

# %%
plt.plot(x,cdf,'.'); # plots

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
plt.plot(cdf,x,'.'); # plots

# %%
def find_nearest(array, value): # finds the nearest array

  idx = np.argmin(np.abs(array - value)) # idx means array- value
  
  return idx # retuns the idx

# %%
find_nearest(cdf, 0.1) # finds the nearest to the line
# Out:
# 393

# %%
x[393] # x value
# Out:
# -1.2792792792792795

# %%
xr = np.random.random((10000,)) # random number generator 1-1000

# %%
w = np.zeros(xr.shape[0]) # w is np.zeros

for i in range(xr.shape[0]): # range 
  
  w[i] = x[find_nearest(cdf, xr[i])] #w[i]= finding the nearest to x

# %%
w.shape # gives a number for w shape
# Out:
# (10000,)

# %%
plt.hist(w,50); # plots a histogram with w and 50

# %%
num_bins = 50 # nunber of bins is 50
n,bins,patches = plt.hist(w, num_bins, density=1) # what number,bins and patches =
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2)) # value of y
plt.plot(bins,y) # plots it on the graph

# %% [markdown]
# # Random Color

# %%
import numpy as np # import numpy as np
import matplotlib.pyplot as plt # import mat plot lib as plt

# %%
z = np.random.randint(0,255,size=(10,10,3)) # the valye of z

# %%
plt.imshow(z) # plots the valued numbers into a map of colors

# %%
z = np.zeros((10,10,3)) # value of z

# %%
plt.imshow(z) # plots z

# %%
z = 0*np.ones((10,10,3)) #plots z again

# %%
plt.imshow(z) # plots the color of z

# %%
z = 255*np.ones((10,10,3)) # plots z after multiplyed by 255

# %%
plt.imshow(z) # the color of z after multiplying
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3)) # z

z[:,:,0] = 1 
z[:,:,1] = 0
z[:,:,2] = 0

plt.imshow(z) # plots the value of from the graph after identifying these numbers

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z) # does the same thing as above, uses the numbers ot identify which color is being used

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 0
z[:,:,2] = 1

plt.imshow(z)# does the same thing as above, uses the numbers ot identify which color is being used

# %%
z = np.ones((10,10,3))

r = np.random.rand() # identifys r
g = np.random.rand() # identifys g
b = np.random.rand() # identifys b

print(r,g,b) # prints all valuables from above 

z[:,:,0] = r
z[:,:,1] = g
z[:,:,2] = b

plt.imshow(z); # chooses color from these numbers after identifying the values of r,g,b
# Out:
# 0.8125222690162505 0.7224054157481967 0.9115143750006839

# %%
for i in range(10): # changes the range to 10

    z = np.ones((10,10,3))

    r = np.random.rand() # what r means 
    g = np.random.rand() # what g means 
    b = np.random.rand() # what b means 

    print(r,g,b) # prints

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z); # plots the numbers after adding a range
    plt.show()
# Out:
# 0.6997099579763754 0.03786564776358625 0.41823180041341823
# 0.5326267448913338 0.8168597570702691 0.03317217383033566
# 0.22967385368699467 0.38408491513904264 0.15336528588806275
# 0.7327370358517993 0.6381354983425281 0.597884174652946
# 0.5460051828909805 0.7978573075799242 0.2272442854186636
# 0.030847324519067132 0.51215672159054 0.16906878449049723
# 0.22535986745576753 0.5009901282678275 0.8324532161976268
# 0.9460128625565254 0.2376906206176267 0.10893410799160486
# 0.7887271065601599 0.5681929022219042 0.7563263202824507
# 0.6185534778704558 0.7058554150154877 0.7957503446688252

# %%
for i in range(10): # range is 10
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    z3 = np.hstack((z1,z2))

    plt.imshow(z3); # plots imshow
    plt.show()

# %%
for i in range(10): #range is 10
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3); #plots 
    plt.show()

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np #imports numpy as np
import matplotlib.pyplot as plt #imports matplot as plt
import matplotlib.colors as mcolors #important mat plot colors as mcolors 
import matplotlib #imports
import imageio #imports 
from PIL import Image #imports as image 

def get_colors_lospec(url):
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %%
url = 'https://lospec.com/palette-list/agb-32x.png' # url

# %%
url = 'https://lospec.com/palette-list/agb-1x.png' # url

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png' #url

# %%
im = imageio.imread(url) #renames imageio as im

# %%
plt.imshow(im); #plots it

# %%
z = np.random.randint(0,255,size=(10,10)) # random randients

# %%
plt.imshow(z, cmap=get_colors_lospec(url)) # plots with the url
plt.colorbar();

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05] # plots np.grid with different numbers 
z = np.sqrt(x**2 + y**2)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)

plt.imshow(z, cmap=get_colors_lospec(url)); #plots np.grid with different numbers
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)*np.sin(3*x)

plt.imshow(z, cmap=get_colors_lospec(url)); #plots the np.grid 
plt.show()
